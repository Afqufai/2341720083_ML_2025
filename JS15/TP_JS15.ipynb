# %% [markdown]
# # Jobsheet 15 - Pipeline ML & Deployment
#
# Nama: Afrizal Qurratul Faizin
#
# NIM: 2341720083
#
# ## Tugas
# Setelah berhasil melakukan deployment pada studi kasus latihan ("Day vs Night"), tugas Anda selanjutnya adalah menerapkan pipeline deployment yang sama untuk model Project anda masing-masing.

# %% [markdown]
# ## Deployment
# Model yang dibuat berdasarkan model project menggunakan Project Kelompok PBL sebagai basis telah di-deploy pada link dibawah ini:
#
# https://github.com/MiracleCakra/PBL_Jawara_Mobile/tree/main/PCVK
#
# Pada link Github, file `.pkl`, file `.onnx` (pengganti `.h5`), dan file `app.py`/`main.py` terdapat pada repository berikut
#
# https://huggingface.co/spaces/MiracleCakra/CMKESEGARANSAYUR
